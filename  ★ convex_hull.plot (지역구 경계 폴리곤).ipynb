# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# %%
F1 = ' 2023 DATA/대중교통 취약지역/Z_NGII_N3A_G0100000.shp' 
D1 = gpd.read_file(F1, encoding='euc-kr')

# %%
D1.head(5)
# Out:
#                                 UFID        BJCD NAME    DIVI      SCLS  \
# 0  100037608073G01010100000000000006  2644000000  강서구  HJD007  G0018115
# 1  100035909094G01010100000000000040  2641000000  금정구  HJD007  G0018115
# 2  100035909089G01010100000000000042  2671000000  기장군  HJD006  G0018114
# 3  100035913044G01010100000000000049  2629000000   남구  HJD007  G0018115
# 4  100035913042G01010100000000000070  2617000000   동구  HJD007  G0018115
#
#        FMTA     대중교통_                                           geometry
# 0  S2112645  71.36777  MULTIPOLYGON (((1883498.837 3160359.249, 18834...
# 1  S2111860  17.63205  POLYGON ((1909041.598 3195522.524, 1909072.282...
# 2  S2115996  55.54853  MULTIPOLYGON (((1918342.736 3181789.420, 19183...
# 3  S2111359  20.05683  MULTIPOLYGON (((1908774.730 3171219.497, 19087...
# 4  S2119230  19.91595  POLYGON ((1902869.489 3177996.822, 1902898.335...

# %%
D1.convex_hull.plot(color='gray',edgecolor='w',figsize=(15,15))
# Out:
# <Axes: >
